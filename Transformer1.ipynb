# %%
import torch
from torch import nn, optim
import numpy as np
import os
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dataset
from torch.autograd import Variable
from torch.nn import Parameter
from torch import Tensor
from torch.utils.data import DataLoader, Dataset
import math

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
print(torch.cuda.device_count())
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# 1
# True
# 11.8

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        root_dir = './Label_DATA_L'
        self.data = []
        self.labels = []
        self.file_paths = []
        self.label_map = {'No Force': 0, 'Applying Force': 1, 'Deforming': 2, 'Releasing Force': 3}
        self.transform = transform

        for label, idx in self.label_map.items():
            label_dir = os.path.join(root_dir, label)
            for fname in os.listdir(label_dir):
                file_path = os.path.join(label_dir, fname)
                time_series = np.loadtxt(file_path, delimiter=',')
                time_series = torch.tensor(time_series, dtype=torch.float32)
                self.data.append(time_series)
                self.labels.append(idx)
                self.file_paths.append(file_path)  # 파일 경로 추가

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data = self.data[idx]
        if self.transform:
            data = self.transform(data)
        # 데이터, 레이블, 파일 경로를 반환
        return data, self.labels[idx], self.file_paths[idx]

# %%
from torch.utils.data import random_split

# 데이터셋 인스턴스 생성
dataset = TimeSeriesDataset(root_dir='./Label_DATA')


# 데이터셋 크기에 따라 8:2 비율로 분할
#train_size = int(0.8 * len(dataset))
#test_size = len(dataset) - train_size
#train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# 데이터로더 설정
#train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size, shuffle=False)

train_size = int(0.7 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# %%
from torch.nn.utils.rnn import pad_sequence

class PadSequence:
    def __call__(self, batch):
        # batch 내의 시계열 데이터를 Tensor 리스트로 준비
        data = [item[0] for item in batch]
        labels = torch.tensor([item[1] for item in batch], dtype=torch.long)
        data = pad_sequence(data, batch_first=True, padding_value=0)
        file_paths = [item[2] for item in batch]
        return data, labels, file_paths


# 데이터로더에서 이 변환 사용
#train_loader = DataLoader(train_dataset, batch_size, shuffle=True, collate_fn=PadSequence())
#test_loader = DataLoader(test_dataset, batch_size, shuffle=False, collate_fn=PadSequence())
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=PadSequence())
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=PadSequence())
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=PadSequence())

# %%
'''
from torch.utils.data import Subset
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence


class TimeSeriesDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        root_dir = './Label_DATA_L'
        self.data = []
        self.labels = []
        self.file_paths = []
        self.label_map = {'No Force': 0, 'Applying Force': 1, 'Deforming': 2, 'Releasing Force': 3}
        self.transform = transform

        for label, idx in self.label_map.items():
            label_dir = os.path.join(root_dir, label)
            for fname in os.listdir(label_dir):
                file_path = os.path.join(label_dir, fname)
                time_series = np.loadtxt(file_path, delimiter=',')
                time_series = torch.tensor(time_series, dtype=torch.float32)
                self.data.append(time_series)
                self.labels.append(idx)
                self.file_paths.append(file_path)  # 파일 경로 추가

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data = self.data[idx]
        if self.transform:
            data = self.transform(data)
        # 데이터, 레이블, 파일 경로를 반환
        return data, self.labels[idx], self.file_paths[idx]
    
class PadSequence:
    def __call__(self, batch):
        # batch 내의 시계열 데이터를 Tensor 리스트로 준비
        data = [item[0] for item in batch]
        labels = torch.tensor([item[1] for item in batch], dtype=torch.long)
        data = pad_sequence(data, batch_first=True, padding_value=0)
        file_paths = [item[2] for item in batch]
        return data, labels, file_paths
    
def create_data_loaders(dataset, train_size=0.7, val_size=0.2, test_size=0.1, batch_size=64):
    # 데이터 인덱스 생성
    indices = list(range(len(dataset)))
    
    # 훈련, 검증, 테스트 데이터셋 인덱스 분할
    train_val_idx, test_idx = train_test_split(indices, test_size=test_size, stratify=dataset.labels)
    train_idx, val_idx = train_test_split(train_val_idx, test_size=val_size / (train_size + val_size), stratify=[dataset.labels[i] for i in train_val_idx])
    
    # 데이터 로더 생성
    train_loader = DataLoader(Subset(dataset, train_idx), batch_size=batch_size, shuffle=True, collate_fn=PadSequence())
    val_loader = DataLoader(Subset(dataset, val_idx), batch_size=batch_size, shuffle=False, collate_fn=PadSequence())
    test_loader = DataLoader(Subset(dataset, test_idx), batch_size=batch_size, shuffle=False, collate_fn=PadSequence())
    
    return train_loader, val_loader, test_loader

# 데이터셋 인스턴스 생성
dataset = TimeSeriesDataset(root_dir ='./Label_DATA_L')
train_loader, val_loader, test_loader = create_data_loaders(dataset)
'''
# Out:
# "\nfrom torch.utils.data import Subset\nfrom sklearn.model_selection import train_test_split\nfrom torch.utils.data import DataLoader\nfrom torch.nn.utils.rnn import pad_sequence\n\n\nclass TimeSeriesDataset(Dataset):\n    def __init__(self, root_dir, transform=None):\n        root_dir = './Label_DATA_L'\n        self.data = []\n        self.labels = []\n        self.file_paths = []\n        self.label_map = {'No Force': 0, 'Applying Force': 1, 'Deforming': 2, 'Releasing Force': 3}\n        self.transform = transform\n\n        for label, idx in self.label_map.items():\n            label_dir = os.path.join(root_dir, label)\n            for fname in os.listdir(label_dir):\n                file_path = os.path.join(label_dir, fname)\n                time_series = np.loadtxt(file_path, delimiter=',')\n                time_series = torch.tensor(time_series, dtype=torch.float32)\n                self.data.append(time_series)\n                self.labels.append(idx)\n                self.file_paths.append(file_path)  # 파일 경로 추가\n\n    def __len__(self):\n        return len(self.data)\n\n    def __getitem__(self, idx):\n        data = self.data[idx]\n        if self.transform:\n            data = self.transform(data)\n        # 데이터, 레이블, 파일 경로를 반환\n        return data, self.labels[idx], self.file_paths[idx]\n    \nclass PadSequence:\n    def __call__(self, batch):\n        # batch 내의 시계열 데이터를 Tensor 리스트로 준비\n        data = [item[0] for item in batch]\n        labels = torch.tensor([item[1] for item in batch], dtype=torch.long)\n        data = pad_sequence(data, batch_first=True, padding_value=0)\n        file_paths = [item[2] for item in batch]\n        return data, labels, file_paths\n    \ndef create_data_loaders(dataset, train_size=0.7, val_size=0.2, test_size=0.1, batch_size=64):\n    # 데이터 인덱스 생성\n    indices = list(range(len(dataset)))\n    \n    # 훈련, 검증, 테스트 데이터셋 인덱스 분할\n    train_val_idx, test_idx = train_test_split(indices, test_size=test_size, stratify=dataset.labels)\n    train_idx, val_idx = train_test_split(train_val_idx, test_size=val_size / (train_size + val_size), stratify=[dataset.labels[i] for i in train_val_idx])\n    \n    # 데이터 로더 생성\n    train_loader = DataLoader(Subset(dataset, train_idx), batch_size=batch_size, shuffle=True, collate_fn=PadSequence())\n    val_loader = DataLoader(Subset(dataset, val_idx), batch_size=batch_size, shuffle=False, collate_fn=PadSequence())\n    test_loader = DataLoader(Subset(dataset, test_idx), batch_size=batch_size, shuffle=False, collate_fn=PadSequence())\n    \n    return train_loader, val_loader, test_loader\n\n# 데이터셋 인스턴스 생성\ndataset = TimeSeriesDataset(root_dir ='./Label_DATA_L')\ntrain_loader, val_loader, test_loader = create_data_loaders(dataset)\n"

# %%
def count_labels(data_loader):
    label_count = {0: 0, 1: 0, 2: 0, 3: 0}
    for _, labels, _ in data_loader:
        for label in labels:
            label_count[int(label)] += 1
    return label_count

# 각 데이터셋의 라벨 분포 확인
train_label_count = count_labels(train_loader)
val_label_count = count_labels(val_loader)
test_label_count = count_labels(test_loader)

print("Train label distribution:", train_label_count)
print("Validation label distribution:", val_label_count)
print("Test label distribution:", test_label_count)
# Out:
# Train label distribution: {0: 147, 1: 136, 2: 132, 3: 133}
# Validation label distribution: {0: 37, 1: 48, 2: 35, 3: 36}
# Test label distribution: {0: 28, 1: 17, 2: 20, 3: 15}

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000, device=torch.device('cpu')):
        super(PositionalEncoding, self).__init__()
        self.encoding = torch.zeros(max_len, d_model, device=device)
        position = torch.arange(0, max_len, dtype=torch.float, device=device).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model)).to(device)
        self.encoding[:, 0::2] = torch.sin(position * div_term)
        self.encoding[:, 1::2] = torch.cos(position * div_term)
        self.encoding = self.encoding.unsqueeze(0)

    def forward(self, x):
        return x + self.encoding[:, :x.size(1)]

class TransformerModel(nn.Module):
    def __init__(self, input_size, num_classes, d_model=512, nhead=8, num_encoder_layers=3, dim_feedforward=1024, dropout=0.1, device=torch.device('cpu')):
        super(TransformerModel, self).__init__()
        self.input_size = input_size
        self.d_model = d_model
        # 입력 데이터를 d_model 차원으로 변환
        self.embedding = nn.Linear(input_size, d_model)
        #self.relu1 = nn.ReLU()  # 첫 번째 ReLU 활성화 함수 추가
        self.pos_encoder = PositionalEncoding(d_model, device=device)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward, dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_encoder_layers)
        self.fc_out = nn.Linear(d_model, num_classes)
        #self.relu2 = nn.ReLU()  # 출력 전 ReLU 활성화 함수 추가

    def forward(self, src):
        src = self.embedding(src) * math.sqrt(self.d_model)
        #src = self.relu1(src)  # 첫 번째 ReLU 적용
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = output.mean(dim=1)  # 평균 풀링
        output = self.fc_out(output)
        #output = self.relu2(output)  # 출력 전 ReLU 적용
        return output

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import torch.nn.functional as F

def custom_loss(outputs, labels):
    softmax_outputs = F.log_softmax(outputs, dim=1)
    return F.nll_loss(softmax_outputs, labels)

# %%
input_size = 3  # 입력 차원
num_classes = 4  # 클래스 수
num_epochs = 300
learning_rate = 0.00001
model = TransformerModel(input_size, num_classes, device=device).to(device)

from torch.optim.lr_scheduler import StepLR

optimizer = torch.optim.Adam(model.parameters(), learning_rate)
scheduler = StepLR(optimizer, step_size=30, gamma=0.1)
criterion = nn.CrossEntropyLoss()

# %%
model
# Out:
# TransformerModel(
#   (embedding): Linear(in_features=3, out_features=512, bias=True)
#   (pos_encoder): PositionalEncoding()
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1024, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (fc_out): Linear(in_features=512, out_features=4, bias=True)
# )

# %%
import matplotlib.pyplot as plt

# 학습 및 검증 손실과 정확도를 저장할 리스트
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

def train_epoch(model, data_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for batch in data_loader:
        inputs, labels = batch[:2]
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    avg_loss = running_loss / len(data_loader)
    accuracy = correct / total
    return avg_loss, accuracy

def e_model(model, data_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch in data_loader:
            inputs, labels = batch[:2]
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_loss = running_loss / len(data_loader)
    accuracy = correct / total
    return avg_loss, accuracy

# 학습 루프
for epoch in range(num_epochs):
    #scheduler.step()
    train_loss, train_accuracy = train_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_accuracy = e_model(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_accuracy)
    val_accuracies.append(val_accuracy)

    print(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1, Train Loss: 1.3927, Train Accuracy: 0.2391, Val Loss: 1.3516, Val Accuracy: 0.3269
# Epoch 2, Train Loss: 1.3190, Train Accuracy: 0.4380, Val Loss: 1.2616, Val Accuracy: 0.5128
# Epoch 3, Train Loss: 1.2753, Train Accuracy: 0.4197, Val Loss: 1.2145, Val Accuracy: 0.5000
# Epoch 4, Train Loss: 1.2227, Train Accuracy: 0.4142, Val Loss: 1.1725, Val Accuracy: 0.5064
# Epoch 5, Train Loss: 1.1642, Train Accuracy: 0.4745, Val Loss: 1.1121, Val Accuracy: 0.5256
# Epoch 6, Train Loss: 1.1049, Train Accuracy: 0.4818, Val Loss: 1.0888, Val Accuracy: 0.5321
# Epoch 7, Train Loss: 1.0451, Train Accuracy: 0.5693, Val Loss: 1.0270, Val Accuracy: 0.5064
# Epoch 8, Train Loss: 0.9910, Train Accuracy: 0.5255, Val Loss: 0.9774, Val Accuracy: 0.5897
# Epoch 9, Train Loss: 0.9489, Train Accuracy: 0.5821, Val Loss: 0.9731, Val Accuracy: 0.5897
# Epoch 10, Train Loss: 0.8959, Train Accuracy: 0.6442, Val Loss: 0.9171, Val Accuracy: 0.6154
# Epoch 11, Train Loss: 0.8858, Train Accuracy: 0.6369, Val Loss: 1.0071, Val Accuracy: 0.5769
# Epoch 12, Train Loss: 0.8317, Train Accuracy: 0.6496, Val Loss: 0.8879, Val Accuracy: 0.5962
# Epoch 13, Train Loss: 0.8089, Train Accuracy: 0.6314, Val Loss: 0.9269, Val Accuracy: 0.6026
# Epoch 14, Train Loss: 0.7857, Train Accuracy: 0.6734, Val Loss: 0.8668, Val Accuracy: 0.6474
# Epoch 15, Train Loss: 0.7655, Train Accuracy: 0.6861, Val Loss: 0.8526, Val Accuracy: 0.6474
# Epoch 16, Train Loss: 0.7393, Train Accuracy: 0.6697, Val Loss: 0.8792, Val Accuracy: 0.6410
# Epoch 17, Train Loss: 0.7529, Train Accuracy: 0.6715, Val Loss: 0.9215, Val Accuracy: 0.6346
# Epoch 18, Train Loss: 0.7439, Train Accuracy: 0.6825, Val Loss: 0.8922, Val Accuracy: 0.6346
# Epoch 19, Train Loss: 0.7339, Train Accuracy: 0.6843, Val Loss: 0.8789, Val Accuracy: 0.6538
# Epoch 20, Train Loss: 0.7128, Train Accuracy: 0.6788, Val Loss: 0.8795, Val Accuracy: 0.6346
# Epoch 21, Train Loss: 0.7053, Train Accuracy: 0.7007, Val Loss: 0.8995, Val Accuracy: 0.6410
# Epoch 22, Train Loss: 0.7245, Train Accuracy: 0.6989, Val Loss: 0.8729, Val Accuracy: 0.6410
# Epoch 23, Train Loss: 0.7190, Train Accuracy: 0.6642, Val Loss: 0.9636, Val Accuracy: 0.6282
# Epoch 24, Train Loss: 0.7528, Train Accuracy: 0.6934, Val Loss: 0.8297, Val Accuracy: 0.6538
# Epoch 25, Train Loss: 0.7156, Train Accuracy: 0.6934, Val Loss: 0.9477, Val Accuracy: 0.6282
# Epoch 26, Train Loss: 0.6849, Train Accuracy: 0.7080, Val Loss: 0.8892, Val Accuracy: 0.6474
# Epoch 27, Train Loss: 0.6910, Train Accuracy: 0.7007, Val Loss: 0.8933, Val Accuracy: 0.6346
# Epoch 28, Train Loss: 0.6986, Train Accuracy: 0.7080, Val Loss: 0.8775, Val Accuracy: 0.6538
# Epoch 29, Train Loss: 0.7024, Train Accuracy: 0.6752, Val Loss: 0.8537, Val Accuracy: 0.6667
# Epoch 30, Train Loss: 0.6845, Train Accuracy: 0.7007, Val Loss: 0.9199, Val Accuracy: 0.6218
# Epoch 31, Train Loss: 0.7006, Train Accuracy: 0.6916, Val Loss: 0.8672, Val Accuracy: 0.6667
# Epoch 32, Train Loss: 0.6822, Train Accuracy: 0.7026, Val Loss: 0.8899, Val Accuracy: 0.6538
# Epoch 33, Train Loss: 0.6845, Train Accuracy: 0.7062, Val Loss: 0.8478, Val Accuracy: 0.6859
# Epoch 34, Train Loss: 0.7106, Train Accuracy: 0.6770, Val Loss: 0.9607, Val Accuracy: 0.6346
# Epoch 35, Train Loss: 0.7112, Train Accuracy: 0.6953, Val Loss: 0.8595, Val Accuracy: 0.6667
# Epoch 36, Train Loss: 0.6806, Train Accuracy: 0.7226, Val Loss: 0.8944, Val Accuracy: 0.6474
# Epoch 37, Train Loss: 0.6916, Train Accuracy: 0.6807, Val Loss: 0.8529, Val Accuracy: 0.6603
# Epoch 38, Train Loss: 0.6928, Train Accuracy: 0.7263, Val Loss: 0.8466, Val Accuracy: 0.6795
# Epoch 39, Train Loss: 0.6709, Train Accuracy: 0.7007, Val Loss: 0.8958, Val Accuracy: 0.6474
# Epoch 40, Train Loss: 0.6768, Train Accuracy: 0.7062, Val Loss: 0.8948, Val Accuracy: 0.6474
# Epoch 41, Train Loss: 0.6812, Train Accuracy: 0.6807, Val Loss: 0.8911, Val Accuracy: 0.6346
# Epoch 42, Train Loss: 0.6752, Train Accuracy: 0.7190, Val Loss: 0.8565, Val Accuracy: 0.6603
# Epoch 43, Train Loss: 0.6720, Train Accuracy: 0.6989, Val Loss: 0.8886, Val Accuracy: 0.6538
# Epoch 44, Train Loss: 0.6719, Train Accuracy: 0.7117, Val Loss: 0.8462, Val Accuracy: 0.6795
# Epoch 45, Train Loss: 0.6790, Train Accuracy: 0.6916, Val Loss: 0.8955, Val Accuracy: 0.6410
# Epoch 46, Train Loss: 0.6704, Train Accuracy: 0.7135, Val Loss: 0.8540, Val Accuracy: 0.6731
# Epoch 47, Train Loss: 0.6753, Train Accuracy: 0.7062, Val Loss: 0.8568, Val Accuracy: 0.6538
# Epoch 48, Train Loss: 0.6701, Train Accuracy: 0.7080, Val Loss: 0.8512, Val Accuracy: 0.6795
# Epoch 49, Train Loss: 0.6627, Train Accuracy: 0.7117, Val Loss: 0.8901, Val Accuracy: 0.6667
# Epoch 50, Train Loss: 0.6596, Train Accuracy: 0.7099, Val Loss: 0.8460, Val Accuracy: 0.6859
# Epoch 51, Train Loss: 0.6638, Train Accuracy: 0.7153, Val Loss: 0.9119, Val Accuracy: 0.6282
# Epoch 52, Train Loss: 0.6618, Train Accuracy: 0.7044, Val Loss: 0.8869, Val Accuracy: 0.6603
# Epoch 53, Train Loss: 0.6694, Train Accuracy: 0.7062, Val Loss: 0.8452, Val Accuracy: 0.6859
# Epoch 54, Train Loss: 0.6769, Train Accuracy: 0.6880, Val Loss: 0.8776, Val Accuracy: 0.6474
# Epoch 55, Train Loss: 0.6553, Train Accuracy: 0.7172, Val Loss: 0.8648, Val Accuracy: 0.6603
# Epoch 56, Train Loss: 0.6833, Train Accuracy: 0.7208, Val Loss: 0.8676, Val Accuracy: 0.6603
# Epoch 57, Train Loss: 0.6710, Train Accuracy: 0.6916, Val Loss: 0.8791, Val Accuracy: 0.6603
# Epoch 58, Train Loss: 0.6549, Train Accuracy: 0.7080, Val Loss: 0.8656, Val Accuracy: 0.6731
# Epoch 59, Train Loss: 0.6647, Train Accuracy: 0.7153, Val Loss: 0.9114, Val Accuracy: 0.6346
# Epoch 60, Train Loss: 0.6620, Train Accuracy: 0.7080, Val Loss: 0.8586, Val Accuracy: 0.6603
# Epoch 61, Train Loss: 0.6676, Train Accuracy: 0.7080, Val Loss: 0.8689, Val Accuracy: 0.6667
# Epoch 62, Train Loss: 0.6745, Train Accuracy: 0.7190, Val Loss: 0.8858, Val Accuracy: 0.6667
# Epoch 63, Train Loss: 0.6660, Train Accuracy: 0.7172, Val Loss: 0.8939, Val Accuracy: 0.6538
# Epoch 64, Train Loss: 0.6639, Train Accuracy: 0.7062, Val Loss: 0.8489, Val Accuracy: 0.6795
# Epoch 65, Train Loss: 0.6508, Train Accuracy: 0.7172, Val Loss: 0.8745, Val Accuracy: 0.6538
# Epoch 66, Train Loss: 0.6469, Train Accuracy: 0.7318, Val Loss: 0.8691, Val Accuracy: 0.6603
# Epoch 67, Train Loss: 0.6515, Train Accuracy: 0.7208, Val Loss: 0.8574, Val Accuracy: 0.6731
# Epoch 68, Train Loss: 0.6493, Train Accuracy: 0.7172, Val Loss: 0.8823, Val Accuracy: 0.6603
# Epoch 69, Train Loss: 0.6563, Train Accuracy: 0.7208, Val Loss: 0.8844, Val Accuracy: 0.6603
# Epoch 70, Train Loss: 0.6564, Train Accuracy: 0.7299, Val Loss: 0.8618, Val Accuracy: 0.6859
# Epoch 71, Train Loss: 0.6581, Train Accuracy: 0.7172, Val Loss: 0.8775, Val Accuracy: 0.6859
# Epoch 72, Train Loss: 0.6336, Train Accuracy: 0.7245, Val Loss: 0.8529, Val Accuracy: 0.6795
# Epoch 73, Train Loss: 0.6335, Train Accuracy: 0.7263, Val Loss: 0.8918, Val Accuracy: 0.6795
# Epoch 74, Train Loss: 0.6380, Train Accuracy: 0.7226, Val Loss: 0.8873, Val Accuracy: 0.6667
# Epoch 75, Train Loss: 0.6468, Train Accuracy: 0.7172, Val Loss: 0.9073, Val Accuracy: 0.6603
# Epoch 76, Train Loss: 0.6486, Train Accuracy: 0.7172, Val Loss: 0.8541, Val Accuracy: 0.6667
# Epoch 77, Train Loss: 0.6569, Train Accuracy: 0.7190, Val Loss: 0.9179, Val Accuracy: 0.6474
# Epoch 78, Train Loss: 0.6431, Train Accuracy: 0.7263, Val Loss: 0.8535, Val Accuracy: 0.6731
# Epoch 79, Train Loss: 0.6418, Train Accuracy: 0.7208, Val Loss: 0.8861, Val Accuracy: 0.6667
# Epoch 80, Train Loss: 0.6459, Train Accuracy: 0.7026, Val Loss: 0.8513, Val Accuracy: 0.6667
# Epoch 81, Train Loss: 0.6508, Train Accuracy: 0.7245, Val Loss: 0.9214, Val Accuracy: 0.6410
# Epoch 82, Train Loss: 0.6644, Train Accuracy: 0.7080, Val Loss: 0.8530, Val Accuracy: 0.6859
# Epoch 83, Train Loss: 0.6536, Train Accuracy: 0.7135, Val Loss: 0.8824, Val Accuracy: 0.6731
# Epoch 84, Train Loss: 0.6343, Train Accuracy: 0.7208, Val Loss: 0.8675, Val Accuracy: 0.6667
# Epoch 85, Train Loss: 0.6463, Train Accuracy: 0.7172, Val Loss: 0.8946, Val Accuracy: 0.6538
# Epoch 86, Train Loss: 0.6379, Train Accuracy: 0.7226, Val Loss: 0.8487, Val Accuracy: 0.6667
# Epoch 87, Train Loss: 0.6434, Train Accuracy: 0.7117, Val Loss: 0.8834, Val Accuracy: 0.6731
# Epoch 88, Train Loss: 0.6429, Train Accuracy: 0.7281, Val Loss: 0.8755, Val Accuracy: 0.6731
# Epoch 89, Train Loss: 0.6440, Train Accuracy: 0.7299, Val Loss: 0.8609, Val Accuracy: 0.6731
# Epoch 90, Train Loss: 0.6498, Train Accuracy: 0.7226, Val Loss: 0.9371, Val Accuracy: 0.6474
# Epoch 91, Train Loss: 0.6636, Train Accuracy: 0.7190, Val Loss: 0.8456, Val Accuracy: 0.6795
# Epoch 92, Train Loss: 0.6772, Train Accuracy: 0.6880, Val Loss: 0.9232, Val Accuracy: 0.6346
# Epoch 93, Train Loss: 0.6408, Train Accuracy: 0.7172, Val Loss: 0.8680, Val Accuracy: 0.6667
# Epoch 94, Train Loss: 0.6268, Train Accuracy: 0.7226, Val Loss: 0.8688, Val Accuracy: 0.6795
# Epoch 95, Train Loss: 0.6312, Train Accuracy: 0.7391, Val Loss: 0.8979, Val Accuracy: 0.6667
# Epoch 96, Train Loss: 0.6311, Train Accuracy: 0.7336, Val Loss: 0.8659, Val Accuracy: 0.6923
# Epoch 97, Train Loss: 0.6207, Train Accuracy: 0.7391, Val Loss: 0.8868, Val Accuracy: 0.6859
# Epoch 98, Train Loss: 0.6273, Train Accuracy: 0.7372, Val Loss: 0.8611, Val Accuracy: 0.6859
# Epoch 99, Train Loss: 0.6412, Train Accuracy: 0.7281, Val Loss: 0.8922, Val Accuracy: 0.6731
# Epoch 100, Train Loss: 0.6304, Train Accuracy: 0.7299, Val Loss: 0.8904, Val Accuracy: 0.6667
# Epoch 101, Train Loss: 0.6261, Train Accuracy: 0.7354, Val Loss: 0.8834, Val Accuracy: 0.6795
# Epoch 102, Train Loss: 0.6338, Train Accuracy: 0.7281, Val Loss: 0.8761, Val Accuracy: 0.6859
# Epoch 103, Train Loss: 0.6340, Train Accuracy: 0.7263, Val Loss: 0.8723, Val Accuracy: 0.6795
# Epoch 104, Train Loss: 0.6259, Train Accuracy: 0.7190, Val Loss: 0.8654, Val Accuracy: 0.6795
# Epoch 105, Train Loss: 0.6374, Train Accuracy: 0.7263, Val Loss: 0.8840, Val Accuracy: 0.6795
# Epoch 106, Train Loss: 0.6306, Train Accuracy: 0.7299, Val Loss: 0.8641, Val Accuracy: 0.6859
# Epoch 107, Train Loss: 0.6486, Train Accuracy: 0.7354, Val Loss: 0.8702, Val Accuracy: 0.6987
# Epoch 108, Train Loss: 0.6231, Train Accuracy: 0.7281, Val Loss: 0.8672, Val Accuracy: 0.6667
# Epoch 109, Train Loss: 0.6324, Train Accuracy: 0.7354, Val Loss: 0.8664, Val Accuracy: 0.6731
# Epoch 110, Train Loss: 0.6313, Train Accuracy: 0.7263, Val Loss: 0.8746, Val Accuracy: 0.6731
# Epoch 111, Train Loss: 0.6187, Train Accuracy: 0.7354, Val Loss: 0.8810, Val Accuracy: 0.6795
# Epoch 112, Train Loss: 0.6210, Train Accuracy: 0.7318, Val Loss: 0.8684, Val Accuracy: 0.6795
# Epoch 113, Train Loss: 0.6268, Train Accuracy: 0.7245, Val Loss: 0.8584, Val Accuracy: 0.6859
# Epoch 114, Train Loss: 0.6221, Train Accuracy: 0.7409, Val Loss: 0.8802, Val Accuracy: 0.6795
# Epoch 115, Train Loss: 0.6243, Train Accuracy: 0.7391, Val Loss: 0.8550, Val Accuracy: 0.6859
# Epoch 116, Train Loss: 0.6519, Train Accuracy: 0.7245, Val Loss: 0.8763, Val Accuracy: 0.6731
# Epoch 117, Train Loss: 0.6169, Train Accuracy: 0.7372, Val Loss: 0.8731, Val Accuracy: 0.6795
# Epoch 118, Train Loss: 0.6140, Train Accuracy: 0.7245, Val Loss: 0.8888, Val Accuracy: 0.6603
# Epoch 119, Train Loss: 0.6292, Train Accuracy: 0.7464, Val Loss: 0.8704, Val Accuracy: 0.6731
# Epoch 120, Train Loss: 0.6301, Train Accuracy: 0.7318, Val Loss: 0.8524, Val Accuracy: 0.6731
# Epoch 121, Train Loss: 0.6555, Train Accuracy: 0.7281, Val Loss: 0.8887, Val Accuracy: 0.6667
# Epoch 122, Train Loss: 0.6070, Train Accuracy: 0.7409, Val Loss: 0.8660, Val Accuracy: 0.6731
# Epoch 123, Train Loss: 0.6371, Train Accuracy: 0.7263, Val Loss: 0.8695, Val Accuracy: 0.6731
# Epoch 124, Train Loss: 0.6378, Train Accuracy: 0.7372, Val Loss: 0.9138, Val Accuracy: 0.6474
# Epoch 125, Train Loss: 0.6123, Train Accuracy: 0.7318, Val Loss: 0.8485, Val Accuracy: 0.6731
# Epoch 126, Train Loss: 0.6288, Train Accuracy: 0.7190, Val Loss: 0.9107, Val Accuracy: 0.6474
# Epoch 127, Train Loss: 0.6155, Train Accuracy: 0.7336, Val Loss: 0.8539, Val Accuracy: 0.6795
# Epoch 128, Train Loss: 0.6150, Train Accuracy: 0.7445, Val Loss: 0.8678, Val Accuracy: 0.6795
# Epoch 129, Train Loss: 0.6081, Train Accuracy: 0.7281, Val Loss: 0.8980, Val Accuracy: 0.6538
# Epoch 130, Train Loss: 0.6055, Train Accuracy: 0.7409, Val Loss: 0.8460, Val Accuracy: 0.6859
# Epoch 131, Train Loss: 0.6109, Train Accuracy: 0.7354, Val Loss: 0.9142, Val Accuracy: 0.6603
# Epoch 132, Train Loss: 0.6214, Train Accuracy: 0.7190, Val Loss: 0.8395, Val Accuracy: 0.6795
# Epoch 133, Train Loss: 0.6363, Train Accuracy: 0.7281, Val Loss: 0.9153, Val Accuracy: 0.6410
# Epoch 134, Train Loss: 0.6185, Train Accuracy: 0.7281, Val Loss: 0.8439, Val Accuracy: 0.6667
# Epoch 135, Train Loss: 0.6277, Train Accuracy: 0.7354, Val Loss: 0.8805, Val Accuracy: 0.6731
# Epoch 136, Train Loss: 0.6069, Train Accuracy: 0.7427, Val Loss: 0.8712, Val Accuracy: 0.6603
# Epoch 137, Train Loss: 0.5975, Train Accuracy: 0.7336, Val Loss: 0.8857, Val Accuracy: 0.6859
# Epoch 138, Train Loss: 0.5995, Train Accuracy: 0.7536, Val Loss: 0.8570, Val Accuracy: 0.6667
# Epoch 139, Train Loss: 0.6017, Train Accuracy: 0.7500, Val Loss: 0.9182, Val Accuracy: 0.6346
# Epoch 140, Train Loss: 0.6042, Train Accuracy: 0.7445, Val Loss: 0.8728, Val Accuracy: 0.6603
# Epoch 141, Train Loss: 0.6338, Train Accuracy: 0.7007, Val Loss: 0.9475, Val Accuracy: 0.6218
# Epoch 142, Train Loss: 0.6273, Train Accuracy: 0.7354, Val Loss: 0.8616, Val Accuracy: 0.6474
# Epoch 143, Train Loss: 0.6202, Train Accuracy: 0.7153, Val Loss: 0.9267, Val Accuracy: 0.6218
# Epoch 144, Train Loss: 0.6280, Train Accuracy: 0.7263, Val Loss: 0.8908, Val Accuracy: 0.6731
# Epoch 145, Train Loss: 0.5997, Train Accuracy: 0.7518, Val Loss: 0.8521, Val Accuracy: 0.6603
# Epoch 146, Train Loss: 0.6063, Train Accuracy: 0.7445, Val Loss: 0.8887, Val Accuracy: 0.6667
# Epoch 147, Train Loss: 0.5951, Train Accuracy: 0.7445, Val Loss: 0.8683, Val Accuracy: 0.6731
# Epoch 148, Train Loss: 0.6180, Train Accuracy: 0.7427, Val Loss: 0.9199, Val Accuracy: 0.6603
# Epoch 149, Train Loss: 0.6157, Train Accuracy: 0.7245, Val Loss: 0.8666, Val Accuracy: 0.6667
# Epoch 150, Train Loss: 0.6146, Train Accuracy: 0.7391, Val Loss: 0.8722, Val Accuracy: 0.6667
# Epoch 151, Train Loss: 0.6119, Train Accuracy: 0.7372, Val Loss: 0.9116, Val Accuracy: 0.6603
# Epoch 152, Train Loss: 0.6375, Train Accuracy: 0.7354, Val Loss: 0.8504, Val Accuracy: 0.6667
# Epoch 153, Train Loss: 0.6039, Train Accuracy: 0.7409, Val Loss: 0.9188, Val Accuracy: 0.6410
# Epoch 154, Train Loss: 0.6086, Train Accuracy: 0.7464, Val Loss: 0.8714, Val Accuracy: 0.6795
# Epoch 155, Train Loss: 0.6036, Train Accuracy: 0.7336, Val Loss: 0.8728, Val Accuracy: 0.6667
# Epoch 156, Train Loss: 0.5958, Train Accuracy: 0.7427, Val Loss: 0.9008, Val Accuracy: 0.6538
# Epoch 157, Train Loss: 0.5915, Train Accuracy: 0.7445, Val Loss: 0.8605, Val Accuracy: 0.6795
# Epoch 158, Train Loss: 0.5933, Train Accuracy: 0.7445, Val Loss: 0.9003, Val Accuracy: 0.6667
# Epoch 159, Train Loss: 0.6041, Train Accuracy: 0.7464, Val Loss: 0.8622, Val Accuracy: 0.6667
# Epoch 160, Train Loss: 0.5978, Train Accuracy: 0.7409, Val Loss: 0.8948, Val Accuracy: 0.6667
# Epoch 161, Train Loss: 0.5947, Train Accuracy: 0.7372, Val Loss: 0.8575, Val Accuracy: 0.6731
# Epoch 162, Train Loss: 0.6002, Train Accuracy: 0.7482, Val Loss: 0.8940, Val Accuracy: 0.6603
# Epoch 163, Train Loss: 0.6000, Train Accuracy: 0.7555, Val Loss: 0.8841, Val Accuracy: 0.6603
# Epoch 164, Train Loss: 0.5952, Train Accuracy: 0.7318, Val Loss: 0.8928, Val Accuracy: 0.6603
# Epoch 165, Train Loss: 0.5995, Train Accuracy: 0.7500, Val Loss: 0.9094, Val Accuracy: 0.6538
# Epoch 166, Train Loss: 0.5993, Train Accuracy: 0.7391, Val Loss: 0.8676, Val Accuracy: 0.6603
# Epoch 167, Train Loss: 0.5885, Train Accuracy: 0.7427, Val Loss: 0.8927, Val Accuracy: 0.6731
# Epoch 168, Train Loss: 0.5941, Train Accuracy: 0.7427, Val Loss: 0.8867, Val Accuracy: 0.6603
# Epoch 169, Train Loss: 0.5966, Train Accuracy: 0.7391, Val Loss: 0.8876, Val Accuracy: 0.6603
# Epoch 170, Train Loss: 0.5755, Train Accuracy: 0.7445, Val Loss: 0.8737, Val Accuracy: 0.6474
# Epoch 171, Train Loss: 0.5783, Train Accuracy: 0.7500, Val Loss: 0.8697, Val Accuracy: 0.6731
# Epoch 172, Train Loss: 0.5777, Train Accuracy: 0.7518, Val Loss: 0.8781, Val Accuracy: 0.6603
# Epoch 173, Train Loss: 0.6122, Train Accuracy: 0.7427, Val Loss: 0.9069, Val Accuracy: 0.6538
# Epoch 174, Train Loss: 0.6012, Train Accuracy: 0.7336, Val Loss: 0.9049, Val Accuracy: 0.6538
# Epoch 175, Train Loss: 0.6271, Train Accuracy: 0.7263, Val Loss: 0.8712, Val Accuracy: 0.6795
# Epoch 176, Train Loss: 0.6119, Train Accuracy: 0.7427, Val Loss: 0.9425, Val Accuracy: 0.6090
# Epoch 177, Train Loss: 0.5951, Train Accuracy: 0.7646, Val Loss: 0.8616, Val Accuracy: 0.6667
# Epoch 178, Train Loss: 0.6146, Train Accuracy: 0.7427, Val Loss: 0.9542, Val Accuracy: 0.6282
# Epoch 179, Train Loss: 0.5984, Train Accuracy: 0.7445, Val Loss: 0.8497, Val Accuracy: 0.6731
# Epoch 180, Train Loss: 0.6063, Train Accuracy: 0.7464, Val Loss: 0.9093, Val Accuracy: 0.6474
# Epoch 181, Train Loss: 0.5937, Train Accuracy: 0.7518, Val Loss: 0.8876, Val Accuracy: 0.6538
# Epoch 182, Train Loss: 0.5889, Train Accuracy: 0.7464, Val Loss: 0.8727, Val Accuracy: 0.6538
# Epoch 183, Train Loss: 0.5858, Train Accuracy: 0.7427, Val Loss: 0.8965, Val Accuracy: 0.6667
# Epoch 184, Train Loss: 0.5825, Train Accuracy: 0.7628, Val Loss: 0.8953, Val Accuracy: 0.6731
# Epoch 185, Train Loss: 0.5817, Train Accuracy: 0.7555, Val Loss: 0.8714, Val Accuracy: 0.6731
# Epoch 186, Train Loss: 0.5962, Train Accuracy: 0.7354, Val Loss: 0.9260, Val Accuracy: 0.6731
# Epoch 187, Train Loss: 0.5980, Train Accuracy: 0.7500, Val Loss: 0.8823, Val Accuracy: 0.6795
# Epoch 188, Train Loss: 0.6310, Train Accuracy: 0.7299, Val Loss: 0.9237, Val Accuracy: 0.6410
# Epoch 189, Train Loss: 0.5977, Train Accuracy: 0.7500, Val Loss: 0.8877, Val Accuracy: 0.6474
# Epoch 190, Train Loss: 0.6135, Train Accuracy: 0.7500, Val Loss: 0.8748, Val Accuracy: 0.6603
# Epoch 191, Train Loss: 0.6297, Train Accuracy: 0.7172, Val Loss: 0.9484, Val Accuracy: 0.6538
# Epoch 192, Train Loss: 0.5973, Train Accuracy: 0.7372, Val Loss: 0.8767, Val Accuracy: 0.6538
# Epoch 193, Train Loss: 0.5868, Train Accuracy: 0.7391, Val Loss: 0.8809, Val Accuracy: 0.6667
# Epoch 194, Train Loss: 0.5991, Train Accuracy: 0.7336, Val Loss: 0.9074, Val Accuracy: 0.6731
# Epoch 195, Train Loss: 0.5859, Train Accuracy: 0.7409, Val Loss: 0.8707, Val Accuracy: 0.6538
# Epoch 196, Train Loss: 0.6057, Train Accuracy: 0.7445, Val Loss: 0.9469, Val Accuracy: 0.6474
# Epoch 197, Train Loss: 0.5964, Train Accuracy: 0.7445, Val Loss: 0.8801, Val Accuracy: 0.6667
# Epoch 198, Train Loss: 0.5868, Train Accuracy: 0.7536, Val Loss: 0.9002, Val Accuracy: 0.6731
# Epoch 199, Train Loss: 0.5877, Train Accuracy: 0.7409, Val Loss: 0.8716, Val Accuracy: 0.6603
# Epoch 200, Train Loss: 0.5779, Train Accuracy: 0.7445, Val Loss: 0.9069, Val Accuracy: 0.6474
# Epoch 201, Train Loss: 0.6005, Train Accuracy: 0.7391, Val Loss: 0.8861, Val Accuracy: 0.6538
# Epoch 202, Train Loss: 0.5750, Train Accuracy: 0.7464, Val Loss: 0.8890, Val Accuracy: 0.6603
# Epoch 203, Train Loss: 0.5754, Train Accuracy: 0.7664, Val Loss: 0.8810, Val Accuracy: 0.6603
# Epoch 204, Train Loss: 0.5847, Train Accuracy: 0.7536, Val Loss: 0.9164, Val Accuracy: 0.6410
# Epoch 205, Train Loss: 0.5818, Train Accuracy: 0.7664, Val Loss: 0.8993, Val Accuracy: 0.6603
# Epoch 206, Train Loss: 0.6009, Train Accuracy: 0.7555, Val Loss: 0.8819, Val Accuracy: 0.6731
# Epoch 207, Train Loss: 0.5768, Train Accuracy: 0.7555, Val Loss: 0.9411, Val Accuracy: 0.6154
# Epoch 208, Train Loss: 0.5764, Train Accuracy: 0.7518, Val Loss: 0.8680, Val Accuracy: 0.6538
# Epoch 209, Train Loss: 0.5876, Train Accuracy: 0.7299, Val Loss: 0.9156, Val Accuracy: 0.6474
# Epoch 210, Train Loss: 0.5604, Train Accuracy: 0.7591, Val Loss: 0.8784, Val Accuracy: 0.6667
# Epoch 211, Train Loss: 0.5836, Train Accuracy: 0.7646, Val Loss: 0.9596, Val Accuracy: 0.6218
# Epoch 212, Train Loss: 0.5637, Train Accuracy: 0.7591, Val Loss: 0.8735, Val Accuracy: 0.6410
# Epoch 213, Train Loss: 0.5614, Train Accuracy: 0.7409, Val Loss: 0.8862, Val Accuracy: 0.6731
# Epoch 214, Train Loss: 0.5594, Train Accuracy: 0.7591, Val Loss: 0.8937, Val Accuracy: 0.6859
# Epoch 215, Train Loss: 0.5678, Train Accuracy: 0.7573, Val Loss: 0.8734, Val Accuracy: 0.6538
# Epoch 216, Train Loss: 0.5947, Train Accuracy: 0.7464, Val Loss: 0.9780, Val Accuracy: 0.6218
# Epoch 217, Train Loss: 0.5900, Train Accuracy: 0.7318, Val Loss: 0.8853, Val Accuracy: 0.6603
# Epoch 218, Train Loss: 0.6136, Train Accuracy: 0.7391, Val Loss: 0.9235, Val Accuracy: 0.6538
# Epoch 219, Train Loss: 0.5757, Train Accuracy: 0.7482, Val Loss: 0.8718, Val Accuracy: 0.6667
# Epoch 220, Train Loss: 0.5621, Train Accuracy: 0.7646, Val Loss: 0.8996, Val Accuracy: 0.6474
# Epoch 221, Train Loss: 0.5828, Train Accuracy: 0.7536, Val Loss: 0.9159, Val Accuracy: 0.6603
# Epoch 222, Train Loss: 0.5670, Train Accuracy: 0.7536, Val Loss: 0.8923, Val Accuracy: 0.6603
# Epoch 223, Train Loss: 0.5589, Train Accuracy: 0.7628, Val Loss: 0.9153, Val Accuracy: 0.6667
# Epoch 224, Train Loss: 0.5497, Train Accuracy: 0.7609, Val Loss: 0.8996, Val Accuracy: 0.6731
# Epoch 225, Train Loss: 0.5509, Train Accuracy: 0.7664, Val Loss: 0.9196, Val Accuracy: 0.6603
# Epoch 226, Train Loss: 0.5667, Train Accuracy: 0.7628, Val Loss: 0.8929, Val Accuracy: 0.6474
# Epoch 227, Train Loss: 0.5622, Train Accuracy: 0.7628, Val Loss: 0.9298, Val Accuracy: 0.6538
# Epoch 228, Train Loss: 0.5590, Train Accuracy: 0.7737, Val Loss: 0.8965, Val Accuracy: 0.6538
# Epoch 229, Train Loss: 0.5470, Train Accuracy: 0.7792, Val Loss: 0.9589, Val Accuracy: 0.6538
# Epoch 230, Train Loss: 0.5620, Train Accuracy: 0.7591, Val Loss: 0.8799, Val Accuracy: 0.6346
# Epoch 231, Train Loss: 0.6000, Train Accuracy: 0.7464, Val Loss: 0.9894, Val Accuracy: 0.6346
# Epoch 232, Train Loss: 0.5761, Train Accuracy: 0.7464, Val Loss: 0.8743, Val Accuracy: 0.6538
# Epoch 233, Train Loss: 0.5604, Train Accuracy: 0.7701, Val Loss: 0.9718, Val Accuracy: 0.6346
# Epoch 234, Train Loss: 0.5624, Train Accuracy: 0.7701, Val Loss: 0.8828, Val Accuracy: 0.6667
# Epoch 235, Train Loss: 0.5627, Train Accuracy: 0.7591, Val Loss: 0.8892, Val Accuracy: 0.6410
# Epoch 236, Train Loss: 0.5404, Train Accuracy: 0.7536, Val Loss: 0.9477, Val Accuracy: 0.6538
# Epoch 237, Train Loss: 0.5523, Train Accuracy: 0.7719, Val Loss: 0.9056, Val Accuracy: 0.6474
# Epoch 238, Train Loss: 0.5608, Train Accuracy: 0.7719, Val Loss: 0.9008, Val Accuracy: 0.6346
# Epoch 239, Train Loss: 0.5661, Train Accuracy: 0.7628, Val Loss: 0.9775, Val Accuracy: 0.6090
# Epoch 240, Train Loss: 0.5735, Train Accuracy: 0.7628, Val Loss: 0.9002, Val Accuracy: 0.6218
# Epoch 241, Train Loss: 0.5535, Train Accuracy: 0.7536, Val Loss: 0.9397, Val Accuracy: 0.6346
# Epoch 242, Train Loss: 0.5406, Train Accuracy: 0.7847, Val Loss: 0.9047, Val Accuracy: 0.6474
# Epoch 243, Train Loss: 0.5488, Train Accuracy: 0.7774, Val Loss: 0.9185, Val Accuracy: 0.6474
# Epoch 244, Train Loss: 0.5325, Train Accuracy: 0.7828, Val Loss: 0.9216, Val Accuracy: 0.6410
# Epoch 245, Train Loss: 0.5655, Train Accuracy: 0.7646, Val Loss: 0.9073, Val Accuracy: 0.6474
# Epoch 246, Train Loss: 0.5336, Train Accuracy: 0.7810, Val Loss: 0.9267, Val Accuracy: 0.6603
# Epoch 247, Train Loss: 0.5341, Train Accuracy: 0.7737, Val Loss: 0.9212, Val Accuracy: 0.6410
# Epoch 248, Train Loss: 0.5304, Train Accuracy: 0.7737, Val Loss: 0.9332, Val Accuracy: 0.6410
# Epoch 249, Train Loss: 0.5514, Train Accuracy: 0.7646, Val Loss: 0.9254, Val Accuracy: 0.6474
# Epoch 250, Train Loss: 0.5409, Train Accuracy: 0.7646, Val Loss: 0.9477, Val Accuracy: 0.6218
# Epoch 251, Train Loss: 0.5458, Train Accuracy: 0.7628, Val Loss: 0.9143, Val Accuracy: 0.6474
# Epoch 252, Train Loss: 0.5501, Train Accuracy: 0.7701, Val Loss: 0.9026, Val Accuracy: 0.6410
# Epoch 253, Train Loss: 0.5525, Train Accuracy: 0.7664, Val Loss: 0.9914, Val Accuracy: 0.6282
# Epoch 254, Train Loss: 0.5440, Train Accuracy: 0.7701, Val Loss: 0.9263, Val Accuracy: 0.6474
# Epoch 255, Train Loss: 0.5331, Train Accuracy: 0.7792, Val Loss: 0.9504, Val Accuracy: 0.6218
# Epoch 256, Train Loss: 0.5478, Train Accuracy: 0.7682, Val Loss: 0.8983, Val Accuracy: 0.6538
# Epoch 257, Train Loss: 0.5573, Train Accuracy: 0.7792, Val Loss: 0.9973, Val Accuracy: 0.6218
# Epoch 258, Train Loss: 0.5399, Train Accuracy: 0.7664, Val Loss: 0.9293, Val Accuracy: 0.6410
# Epoch 259, Train Loss: 0.5394, Train Accuracy: 0.7737, Val Loss: 0.9195, Val Accuracy: 0.6410
# Epoch 260, Train Loss: 0.5390, Train Accuracy: 0.7792, Val Loss: 0.9576, Val Accuracy: 0.6410
# Epoch 261, Train Loss: 0.5190, Train Accuracy: 0.7901, Val Loss: 0.9570, Val Accuracy: 0.6282
# Epoch 262, Train Loss: 0.5340, Train Accuracy: 0.7810, Val Loss: 0.9497, Val Accuracy: 0.6282
# Epoch 263, Train Loss: 0.5376, Train Accuracy: 0.7755, Val Loss: 0.9332, Val Accuracy: 0.6667
# Epoch 264, Train Loss: 0.5302, Train Accuracy: 0.7828, Val Loss: 0.9345, Val Accuracy: 0.6346
# Epoch 265, Train Loss: 0.5396, Train Accuracy: 0.7774, Val Loss: 0.9469, Val Accuracy: 0.6218
# Epoch 266, Train Loss: 0.5322, Train Accuracy: 0.7810, Val Loss: 0.9650, Val Accuracy: 0.6346
# Epoch 267, Train Loss: 0.5193, Train Accuracy: 0.7883, Val Loss: 0.9133, Val Accuracy: 0.6474
# Epoch 268, Train Loss: 0.5197, Train Accuracy: 0.7828, Val Loss: 0.9710, Val Accuracy: 0.6410
# Epoch 269, Train Loss: 0.5157, Train Accuracy: 0.7847, Val Loss: 0.9423, Val Accuracy: 0.6474
# Epoch 270, Train Loss: 0.5441, Train Accuracy: 0.7682, Val Loss: 0.9658, Val Accuracy: 0.6346
# Epoch 271, Train Loss: 0.5248, Train Accuracy: 0.7828, Val Loss: 0.9848, Val Accuracy: 0.6218
# Epoch 272, Train Loss: 0.5163, Train Accuracy: 0.7755, Val Loss: 0.9515, Val Accuracy: 0.6538
# Epoch 273, Train Loss: 0.5092, Train Accuracy: 0.7865, Val Loss: 0.9629, Val Accuracy: 0.6346
# Epoch 274, Train Loss: 0.5296, Train Accuracy: 0.7810, Val Loss: 1.0020, Val Accuracy: 0.6346
# Epoch 275, Train Loss: 0.5351, Train Accuracy: 0.7774, Val Loss: 0.9355, Val Accuracy: 0.6218
# Epoch 276, Train Loss: 0.5265, Train Accuracy: 0.7883, Val Loss: 0.9254, Val Accuracy: 0.6346
# Epoch 277, Train Loss: 0.5138, Train Accuracy: 0.7865, Val Loss: 1.0089, Val Accuracy: 0.6026
# Epoch 278, Train Loss: 0.5306, Train Accuracy: 0.7810, Val Loss: 0.9528, Val Accuracy: 0.6410
# Epoch 279, Train Loss: 0.5112, Train Accuracy: 0.7828, Val Loss: 0.9609, Val Accuracy: 0.6346
# Epoch 280, Train Loss: 0.5158, Train Accuracy: 0.7810, Val Loss: 0.9398, Val Accuracy: 0.6474
# Epoch 281, Train Loss: 0.5107, Train Accuracy: 0.7901, Val Loss: 0.9590, Val Accuracy: 0.6410
# Epoch 282, Train Loss: 0.5064, Train Accuracy: 0.7938, Val Loss: 0.9541, Val Accuracy: 0.6218
# Epoch 283, Train Loss: 0.5165, Train Accuracy: 0.7828, Val Loss: 1.0657, Val Accuracy: 0.6090
# Epoch 284, Train Loss: 0.5443, Train Accuracy: 0.7755, Val Loss: 0.9460, Val Accuracy: 0.6282
# Epoch 285, Train Loss: 0.5447, Train Accuracy: 0.7664, Val Loss: 0.9663, Val Accuracy: 0.6538
# Epoch 286, Train Loss: 0.5263, Train Accuracy: 0.7792, Val Loss: 0.9470, Val Accuracy: 0.6667
# Epoch 287, Train Loss: 0.5315, Train Accuracy: 0.7701, Val Loss: 1.1086, Val Accuracy: 0.5897
# Epoch 288, Train Loss: 0.5519, Train Accuracy: 0.7719, Val Loss: 0.9491, Val Accuracy: 0.6346
# Epoch 289, Train Loss: 0.5350, Train Accuracy: 0.7883, Val Loss: 0.9476, Val Accuracy: 0.6346
# Epoch 290, Train Loss: 0.5091, Train Accuracy: 0.7847, Val Loss: 0.9953, Val Accuracy: 0.6538
# Epoch 291, Train Loss: 0.5145, Train Accuracy: 0.7920, Val Loss: 0.9640, Val Accuracy: 0.6410
# Epoch 292, Train Loss: 0.5186, Train Accuracy: 0.7847, Val Loss: 1.0245, Val Accuracy: 0.6410
# Epoch 293, Train Loss: 0.5496, Train Accuracy: 0.7701, Val Loss: 0.9806, Val Accuracy: 0.6410
# Epoch 294, Train Loss: 0.5340, Train Accuracy: 0.7865, Val Loss: 0.9401, Val Accuracy: 0.6603
# Epoch 295, Train Loss: 0.5250, Train Accuracy: 0.7828, Val Loss: 0.9766, Val Accuracy: 0.6218
# Epoch 296, Train Loss: 0.5162, Train Accuracy: 0.7993, Val Loss: 1.0121, Val Accuracy: 0.6346
# Epoch 297, Train Loss: 0.5244, Train Accuracy: 0.7682, Val Loss: 0.9710, Val Accuracy: 0.6282
# Epoch 298, Train Loss: 0.5156, Train Accuracy: 0.7810, Val Loss: 0.9766, Val Accuracy: 0.6282
# Epoch 299, Train Loss: 0.5189, Train Accuracy: 0.7920, Val Loss: 0.9580, Val Accuracy: 0.6410
# Epoch 300, Train Loss: 0.5117, Train Accuracy: 0.7920, Val Loss: 1.0077, Val Accuracy: 0.6218

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 모델 평가 함수
def evaluate_model(model, data_loader):
    model.eval()
    true_labels = []
    pred_labels = []
    file_paths = []  # 파일 경로 저장
    with torch.no_grad():
        for inputs, labels, paths in data_loader:
            inputs = inputs.float().to(device)  #입력 데이터를 float 타입으로 변환
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            true_labels.extend(labels.cpu().numpy())
            pred_labels.extend(predicted.cpu().numpy())
            file_paths.extend(paths)  # 파일 경로 추가
    return true_labels, pred_labels, file_paths

# 평가 실행
actual_labels, predicted_labels, file_paths = evaluate_model(model, test_loader)
#for path, true_label, pred_label in zip(file_paths, actual_labels, predicted_labels):
    #print(f'File: {path}, Actual Label: {true_label}, Predicted Label: {pred_label}')

# 성능 메트릭 출력
print(classification_report(actual_labels, predicted_labels))
print("Accuracy:", accuracy_score(actual_labels, predicted_labels))

# 혼동 행렬 생성
cm = confusion_matrix(actual_labels, predicted_labels)

# 혼동 행렬 시각화
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=(0, 1, 2, 3), yticklabels=(0, 1, 2, 3))
plt.title('Confusion Matrix')
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.61      0.59        28
#            1       0.57      0.76      0.65        17
#            2       0.50      0.40      0.44        20
#            3       0.91      0.67      0.77        15
#
#     accuracy                           0.60        80
#    macro avg       0.64      0.61      0.61        80
# weighted avg       0.61      0.60      0.60        80
#
# Accuracy: 0.6

# %%
# 평가 실행 및 파일 경로 출력
actual_labels, predicted_labels, file_paths = evaluate_model(model, test_loader)

# 실제 레이블과 예측 레이블이 다른 경우만 출력
for path, true_label, pred_label in zip(file_paths, actual_labels, predicted_labels):
    if true_label != pred_label:
        print(f'File: {path}, Actual Label: {true_label}, Predicted Label: {pred_label}')
# Out:
# File: ./Label_DATA_L\No Force\F17(705-794).csv, Actual Label: 0, Predicted Label: 1
# File: ./Label_DATA_L\Releasing Force\F11(5242-5271).csv, Actual Label: 3, Predicted Label: 1
# File: ./Label_DATA_L\No Force\F2(5937-6001).csv, Actual Label: 0, Predicted Label: 1
# File: ./Label_DATA_L\No Force\F2(5662-5754).csv, Actual Label: 0, Predicted Label: 2
# File: ./Label_DATA_L\No Force\F7(4914-5191).csv, Actual Label: 0, Predicted Label: 2
# File: ./Label_DATA_L\No Force\F16(5967-6001).csv, Actual Label: 0, Predicted Label: 1
# File: ./Label_DATA_L\Applying Force\F17(2506-2572).csv, Actual Label: 1, Predicted Label: 0
# File: ./Label_DATA_L\No Force\F2(4360-4848).csv, Actual Label: 0, Predicted Label: 2
# File: ./Label_DATA_L\No Force\F2(5123-5295).csv, Actual Label: 0, Predicted Label: 2
# File: ./Label_DATA_L\Releasing Force\F1(1249-1269).csv, Actual Label: 3, Predicted Label: 1
# File: ./Label_DATA_L\Deforming\F13(3877-4175).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\Deforming\F20(1895-2161).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\No Force\F16(553-700).csv, Actual Label: 0, Predicted Label: 2
# File: ./Label_DATA_L\Deforming\F2(411-699).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\Applying Force\F1(3723-3820).csv, Actual Label: 1, Predicted Label: 0
# File: ./Label_DATA_L\Releasing Force\F20(5333-5364).csv, Actual Label: 3, Predicted Label: 1
# File: ./Label_DATA_L\Deforming\F4(1337-1366).csv, Actual Label: 2, Predicted Label: 1
# File: ./Label_DATA_L\No Force\F4(1071-1264).csv, Actual Label: 0, Predicted Label: 2
# File: ./Label_DATA_L\Applying Force\F18(4301-4460).csv, Actual Label: 1, Predicted Label: 0
# File: ./Label_DATA_L\Deforming\F18(5951-6001).csv, Actual Label: 2, Predicted Label: 1
# File: ./Label_DATA_L\Deforming\F11(1620-1705).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\Deforming\F21(3707-3976).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\Deforming\F1(2571-2729).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\Releasing Force\F5(4317-4368).csv, Actual Label: 3, Predicted Label: 1
# File: ./Label_DATA_L\Deforming\F8(5464-5565).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\Deforming\F5(1944-2206).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\Deforming\F2(2858-3020).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\Applying Force\F15(3339-3347).csv, Actual Label: 1, Predicted Label: 3
# File: ./Label_DATA_L\Releasing Force\F2(5084-5122).csv, Actual Label: 3, Predicted Label: 1
# File: ./Label_DATA_L\No Force\F8(5241-5412).csv, Actual Label: 0, Predicted Label: 2
# File: ./Label_DATA_L\Deforming\F3(1094-1335).csv, Actual Label: 2, Predicted Label: 0
# File: ./Label_DATA_L\No Force\F11(3986-4270).csv, Actual Label: 0, Predicted Label: 2

# %%
import pandas as pd

# 분류 보고서를 데이터프레임으로 변환
report = classification_report(actual_labels, predicted_labels, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# 분류 보고서 시각화
#df_report.drop(['accuracy'], inplace=True)  # 'accuracy' row는 제외하고 시각화
df_report['support'] = df_report['support'].apply(int)  # support를 정수로 변환

fig, ax = plt.subplots(figsize=(8, 6))
df_report[['precision', 'recall', 'f1-score']].plot(kind='barh', ax=ax)
ax.set_title('Classification Report')
ax.set_xlabel('Score')
plt.show()

# %%
'''
def save_checkpoint(model, optimizer, epoch, loss, filepath):
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
    }, filepath)

save_checkpoint(model, optimizer, epoch, train_loss, './Acc76.pth')
'''
# Out:
# "\ndef save_checkpoint(model, optimizer, epoch, loss, filepath):\n    torch.save({\n        'epoch': epoch,\n        'model_state_dict': model.state_dict(),\n        'optimizer_state_dict': optimizer.state_dict(),\n        'loss': loss,\n    }, filepath)\n\nsave_checkpoint(model, optimizer, epoch, train_loss, './Acc76.pth')\n"

# %%
'''
def load_checkpoint(filepath, model, optimizer):
    checkpoint = torch.load(filepath)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    epoch = checkpoint['epoch']
    loss = checkpoint['loss']
    return model, optimizer, epoch, loss

# 모델과 옵티마이저 인스턴스를 생성한 뒤, 체크포인트 로드
model = TransformerModel(input_size, num_classes, device=device).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# 체크포인트 파일 로드
model, optimizer, start_epoch, last_loss = load_checkpoint('model_checkpoint.pth', model, optimizer)
'''
# Out:
# "\ndef load_checkpoint(filepath, model, optimizer):\n    checkpoint = torch.load(filepath)\n    model.load_state_dict(checkpoint['model_state_dict'])\n    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])\n    epoch = checkpoint['epoch']\n    loss = checkpoint['loss']\n    return model, optimizer, epoch, loss\n\n# 모델과 옵티마이저 인스턴스를 생성한 뒤, 체크포인트 로드\nmodel = TransformerModel(input_size, num_classes, device=device).to(device)\noptimizer = torch.optim.Adam(model.parameters(), lr=0.0001)\n\n# 체크포인트 파일 로드\nmodel, optimizer, start_epoch, last_loss = load_checkpoint('model_checkpoint.pth', model, optimizer)\n"
